# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = io.imread('shiba-p.jpg') # Carregamento da imagem

print(type(img))

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape
# Out:
# (640, 640, 3)

# %%
img_copia = img.copy()
plt.imshow(img_copia)

# %%
img_copia
# Out:
# array([[[ 70,  19,   2],
#         [ 70,  19,   2],
#         [ 70,  19,   2],
#         ...,
#         [135,  46,  28],
#         [135,  46,  28],
#         [137,  48,  30]],
#
#        [[ 70,  19,   2],
#         [ 70,  19,   2],
#         [ 70,  19,   2],
#         ...,
#         [135,  46,  28],
#         [135,  46,  28],
#         [136,  47,  29]],
#
#        [[ 71,  18,   2],
#         [ 70,  19,   2],
#         [ 70,  19,   2],
#         ...,
#         [135,  46,  28],
#         [135,  46,  28],
#         [134,  45,  27]],
#
#        ...,
#
#        [[ 90, 117,  36],
#         [ 91, 118,  37],
#         [ 90, 119,  37],
#         ...,
#         [116, 129,  57],
#         [116, 129,  57],
#         [116, 129,  57]],
#
#        [[ 92, 117,  36],
#         [ 90, 117,  36],
#         [ 91, 118,  37],
#         ...,
#         [117, 130,  58],
#         [116, 129,  57],
#         [116, 130,  55]],
#
#        [[ 92, 117,  36],
#         [ 92, 117,  36],
#         [ 93, 118,  37],
# ...

# %%
'''Cortando na Vertical'''

a = img_copia[:,0:321]

# %%
plt.imshow(a)

# %%
'''Pode ser feito também desta forma:'''

a = img_copia[:,-320:]

# %%
plt.imshow(a)

# %%
'''Cortando na Horizontal'''

b = img_copia[0:321]

# %%
plt.imshow(b)

# %%
'''Também pode ser feito:'''

b = img_copia[-320:]
plt.imshow(b)

# %%
'''Apagando o Nariz'''

nariz_apagado = img_copia
nariz_apagado[290:360, 330:420, [0,1,2]] = 255
plt.imshow(nariz_apagado)

# %%
img_copia.shape
# Out:
# (640, 640, 3)

# %%
escala_cinza = img

plt.imshow(escala_cinza[:,:,0]* 0.299 + escala_cinza[:,:,1]* 0.587 + escala_cinza[:,:,2]* 0.114, cmap ="gray")

                        #Red                         #Green                       #Blue

# %%
'''Obs: O Erivan me ajudou com a parte do nariz, professor.'''
